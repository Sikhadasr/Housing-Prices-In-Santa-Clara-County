# %% [markdown]
# # **HOUSING PRICES IN SANTA CLARA COUNTY**
#
#  ### A project by Ming-Chang Chiang, Katharine Grant, Sikha Rani Das and Saloni Sharma

# %% [markdown]
# ## **PREFACE **

# %% [markdown]
# It is a fact that housing prices in the Bay Area have been skyrocketing over the last decade. The Bay Area is facing a major housing crisis and the prices here are much higher compared to other major cities in USA.
#
# Some of the consequences of the increase in house prices are increased commute length and an exodus from the area, among other issues.
#
# We would like to explore what drives these increased housing prices and hence, the topic for our project is** ‘Housing Prices In Santa Clara County.’**
#
# We plan to explore the relationship between  population, income and  inventory on housing prices, focusing on data from the years 2013 to 2018.
#
# This document consists of the following:
# 1. Problem Statement
# 3. Findings and Visualizations
# 4. Video
# 5. Roadmap
# 6. References

# %% [markdown]
# ## **1. PROBLEM STATEMENT **
#
# ---
#
#
#
# Owning a house is an important dream for a lot of people. Along with providing basic shelter, having a good house affects our daily life in significant number of ways, be it access to education, work, or recreation.
#
# For the purpose of this project, we focused on the Santa Clara County area. We considered the house prices in this area over time and its impact through visualization of relevant data. We have come up with a dashboard that shows the relationship between  median house price, house inventory, median income and population.
#
# ### Target Audience:
# We have developed this project with the "City Council of Santa Clara" in mind as our audience. The reason we chose the City Council as our audience is because they are responsible for deciding of the number of houses that are built. The number of housing units available for sale has a direct relationship with the price of the houses and house owners' expectation.
#
# ### **BACKGROUND: **
#
# Some relevant visualizations that support the above mentioned claims about the high house prices are as follows:
#
# a. The comparison between Santa Clara County and USA as a whole shows a clear picture about the high house price issue in the Bay Area. The median house price in Santa Clara County is drastically higher than other metro areas of the U.S. and has now risen above $1 million.

# %%
from google.colab import files
uploaded = files.upload()

from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('median_sales_price.png')  # choose image location
plt.rcParams['figure.figsize'] = [20, 20]
plt.imshow(image)
#plt.figure(figsize=(20000,10000))
plt.show()
# Out:
#      <input type="file" id="files-b7f36e88-36d8-42e7-8204-d99028f4d783" name="files[]" multiple disabled />
#      <output id="result-b7f36e88-36d8-42e7-8204-d99028f4d783">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving median_sales_price.png to median_sales_price (2).png

# %% [markdown]
# Source:  https://www.redfin.com/blog/data-center

# %% [markdown]
# b. The next chart shows that many workers employed with large tech companies like Google, Amazon, Hulu, etc. cannot afford houses near their workplaces.

# %%
from google.colab import files
uploaded = files.upload()

from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('google.jpeg')  # choose image location
plt.rcParams['figure.figsize'] = [12, 20]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-42ea072f-66c0-4345-8e89-ad011cb6d0c9" name="files[]" multiple disabled />
#      <output id="result-42ea072f-66c0-4345-8e89-ad011cb6d0c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving google.jpeg to google (4).jpeg

# %% [markdown]
# Source: https://www.fastcompany.com/40531163/study-even-apple-and-google-engineers-cant-really-afford-to-live-near-their-offices

# %% [markdown]
# c. Interestingly, a study from NeighborhoodX shows that every neighborhood in San Francisco area is equivalent to posh neighborhoods in some of the most exotic cities in the world like Rome, Florence, Madrid, Cannes, etc.

# %%
from google.colab import files
uploaded = files.upload()

from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('paris1.png')  # choose image location
plt.rcParams['figure.figsize'] = [20, 20]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-81b83982-5567-4e90-8fce-7be577acfe29" name="files[]" multiple disabled />
#      <output id="result-81b83982-5567-4e90-8fce-7be577acfe29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving paris1.png to paris1 (1).png

# %% [markdown]
# Source: https://www.google.com/maps/d/u/0/viewer?mid=1mMDf65CvHNj3TBDrmgzTU8Ca-Pk&ll=37.779937673156255%2C-122.52804087718823&z=14

# %% [markdown]
# **EXPLORATIONS: **
#
# We explored some subject matters that we thought were related to housing prices. They are as follows:
#
# * **Lack of new construction:**
#
# Not enough homes are being built to accommodate the growing population. In this graph from Redfin, we can see how few the new construction listings are compared to the existing homes.

# %%
from google.colab import files
uploaded = files.upload()

from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('new_listings.png')  # choose image location
plt.rcParams['figure.figsize'] = [18, 18]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-082632fb-5425-4bdf-beb8-b4e332f5cc96" name="files[]" multiple disabled />
#      <output id="result-082632fb-5425-4bdf-beb8-b4e332f5cc96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving new_listings.png to new_listings (1).png

# %% [markdown]
# Source : https://www.redfin.com/blog/data-center

# %% [markdown]
# * **Impact of local tax revenue on city planning:**
#
# Because of tax limits established in 1978 by Proposition 13 (https://www.californiataxdata.com/pdf/Prop13.pdf), local governments generally receive more revenue from sales tax and hotel room tax than from property tax. Proposition 13 limited the property tax rates to 1% of a home's taxable value and restricted how quickly that taxable value could increase after a purchase.
#
# Last year, the city of Brisbane hired a consultant who found that the city would make 1 million dollars a year net in tax revenue by approving the 4,400 units development in Baylands. But if the city instead approved a project with a lot more commercial space, a larger hotel and no housing, Brisbane would gain 9 million dollars annually - an amount equivalent to more than half the city's current day-to-day operating budget.
#
# This shows that local governments have less incentive to approve residential houses, which has led to a shortage in new housing developments and an increase in the prices of the current houses in the area.
#
# Source: http://www.latimes.com/politics/la-pol-ca-small-city-controls-big-housing-project-20170728-story.html
#
# * **Rising job numbers:**
#
# Part of the problem is that while available housing has not increased much, there are constantly more jobs in the Bay Area, especially from tech companies, both large corporations and startups. Looking at the increase in job numbers may highlight why the lack of new housing has such an impact on the overall housing market.
#
# Source:  https://www.bls.gov/eag/eag.ca_sanjose_msa.htm
#
# * **School desirability:**
#
# One important factor that affects people’s decision while buying houses is whether or not the house is within the boundary of a school with a good API (Academic Performance Index) or high test scores. A survey of nearly 1,000 prospective home buyers showed that 91 percent said school boundaries were important in their search.
#
# On average, homes in the best school districts are sold for higher prices as compared to similar homes in less popular school districts. This might give us some insight on the rising house prices.
#
# Source: https://www.realtor.com/advice/buy/the-right-school-district-how-much-do-schools-affect-real-estate-prices/
#
# * **Housing Regulations**
#
# One of the main issues related to the availability of houses is the low housing density in most parts of the Bay Area. Current regulations in many cities and neighborhoods often not only restrict the size of houses, but also the size of apartment buildings and condominiums. Restrictions on both new construction and expansions has hindered efforts to increase available housing.
#
# Source:  http://sf-planning.org/zoning-map
#
# ###**OUR PLAN OF ACTION:**
#
# Our plan of action was to analyze our datasets and try to find if our intuition regarding these datasets and their relationship with our main Zillow dataset is correct. Even though we had an idea as to how these matters will relate to each other, there was a high chance that they might interact in a counter-intuitive way.
#
# For this project, we looked at some of the following relationships:
#
# * ‘Current job numbers’ with ‘Residential House Construction Permits’
#
# * ‘Current total population’ with ‘Residential House Construction Permits’
#
# * ‘School ratings’ with ‘Zillow house prices’
#
# * ‘Zoning regulations’ with ‘Residential House Construction Permits’
#
# * ‘New housing construction’ by time and city
#
# * ‘Median Household Income’ with ‘Zillow house prices’ at a city level
#
# * Housing purchases for foreign investments with ‘Zillow house prices’
#
# * Age of homeowners with ‘Zillow house prices’
#
# * ‘House Price’ with ‘Exodus and commute’’
#
# However, we did some background research on the above mentioned parameters and decided to use inventory of houses for sale, income and population to analyze their impact on the housing prices.
# Hence, we concentrated more on these factors when we developed our final dashboard.
#
# Source: https://www.fastcompany.com/40531163/study-even-apple-and-google-engineers-cant-really-afford-to-live-near-their-offices,  https://www.mercurynews.com/2018/04/13/5-ways-to-solve-californias-housing-crisis/

# %% [markdown]
# ##**2. FINDINGS AND VISUALIZATIONS**
#
# ---
#
# All of the datasets we collected were of different granularities. So our first step for each finding was to clean the data, shown in the "DATA CLEANING" process shown below. The datasets used for the following cleaning and visualizations can be found in [this folder](https://drive.google.com/drive/folders/1_00_10Q83xSNzmlG_WSOkg3wf6RgPnwi?usp=sharing).
#
# The following are the various visualizations that we have come up with showing the relationship between various parameters.
#
# **Key Changes**
#
# The biggest changes we made to our final version in comparison to our first version were:
# 1. Including parameters and predicted forecasts on all the charts (to increase situational awareness)
# 2. Adding clearer titles, sources, and proper descriptions of our process (to increase documentation and reduce rebuttals as per the 6 analytic design principals)
# 3. Changing the bar graphs to line graphs to increase the data pixel ratio
# 4. Changing all graph colors to one color to maintain color consistency

# %% [markdown]
# ###Finding 1: Median Sales Price with Inventory and Population
#
# **Audience:** The city council would want its constituents to be satisfied with house prices in this area, especially those who already own a house. To make people happier, the council members likely want house prices not to fall below their current price, but still be brought down to a reasonable level for those who want to buy a house. This visualization will show them how much new housing will impact prices and therefore their constituents.
#
#
# **Claim:** The number of housing units available for sale has a negative relationship with the price of houses and a positive relationship with population. When the supply is lower and population is increasing, the house price should go up.

# %% [markdown]
# #### Data Collection & Wrangling
# To meet the need of the goal (as per GQM), we have used the following datasets:

# %% [markdown]
# **Dataset 1: Inventory for Sale**
#
# **Data Source:** We obtained the inventory dataset from Zillow at the following link:
# https://www.zillow.com/research/data/
#
# **Data cleaning:** Since we are mainly interested in Santa Clara County, we made a new dataframe that contains data for only Santa Clara County. We then removed some unnecessary columns from the dataset:
#    1. We removed the columns for the year 2010, 2011 & 2012 because we were only interested in the data for the last five years.
#    2. Since our extracted dataframe contains data only for Santa Clara County, we removed other columns like RegionType,	CountyName, Metro, State, FullName, and DataTypeDescription that would only be of use if we were looking at multiple places.
#
#
# **Detailed steps are shown below:**

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import seaborn as sns
import pandas as pd
import numpy as np
# %pylab inline

import sklearn as sk
import sklearn.tree as tree
from IPython.display import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5123e76-e3cc-4004-a553-e57074b778aa" name="files[]" multiple disabled />
#      <output id="result-c5123e76-e3cc-4004-a553-e57074b778aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving InventoryMeasure_County_Public.csv to InventoryMeasure_County_Public.csv

# %%
#importing the csv file
df =pd.read_csv('InventoryMeasure_County_Public.csv', index_col=0)
#selecting the row with Santa Clara as index
df_santaclara =df.loc[(df.index=='Santa Clara'), ]

#dropping unwanted columns 
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='2010')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='2011')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='2012')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='RegionType')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='CountyName')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='Metro')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='StateFullName')))]
df_santaclara= df_santaclara[df_santaclara.columns.drop(list(df_santaclara.filter(regex='DataTypeDescription')))]

##Transpose 
df_inventory_santaclara =df_santaclara.transpose()                    
#df_inventory_santaclara =df_inventory_santaclara.iloc[7:,]            ##remove unnecessary columns
## Reset Index
df_inventory_santaclara.reset_index(level=0,inplace=True)
## 
df_inventory_santaclara.columns=['YearMonth','Units']

##Extract year from Date
df_inventory_santaclara['Year']=(df_inventory_santaclara['YearMonth'].str.split('-').str[0])

#average inventory by year
df_inventory_santaclara[['Units']] = df_inventory_santaclara[['Units']].apply(pd.to_numeric)
df_inventory_santaclara[['Year']] = df_inventory_santaclara[['Year']].apply(pd.to_numeric)
avg_inventory_santaclara= df_inventory_santaclara.groupby('Year', as_index=False)['Units'].mean()
avg_inventory_santaclara.columns=['Year','Avg_Units']
avg_inventory_santaclara
# Out:
#    Year    Avg_Units
# 0  2013  1882.083333
# 1  2014  1788.666667
# 2  2015  1660.916667
# 3  2016  1668.666667
# 4  2017  1024.250000
# 5  2018   660.333333

# %% [markdown]
# **Dataset 2: House Prices**
#
# This dataset consists of monthly data from 2008 to 2018. Compared to other data resources of Santa Clara County house prices, such as the Census Bureau or S&P/Case-Shiller Home Price Indices, we found that Zillow has the most updated and county specific information. We define the “house price” as median sales price of all types of houses, which include single family houses, condos, and apartments.
#
# **Data Source:**
# We obtained this dataset from Zillow Research. https://www.zillow.com/research/data/ It consists of datasets of various different regions and states, but we are only interested in the 'Santa Clara' region data.
#
# **Data Cleaning:**
# We extracted the data for the particular region and analyzed it. This dataset is the dataset with which we would like to compare/merge our other datasets with to see if our intuition and research regarding housing prices is correct or not. To clean it for future merging and use, we filtered to only the Santa Clara column and only 2013-2018 and then transposed it so that each month was a row. We also created a copy that was aggregated by year in order to merge with the other datasets.
#
#
# **Detailed steps are shown below:**

# %%
#exploring the sales prices dataset to compare it to the average units. 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9f31c9c-e4ad-4ae0-9fb7-14204bf2702e" name="files[]" multiple disabled />
#      <output id="result-c9f31c9c-e4ad-4ae0-9fb7-14204bf2702e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Sale_Prices_County_Aff.csv to Sale_Prices_County_Aff.csv

# %%
sales = pd.read_csv('Sale_Prices_County_Aff.csv')
SCC_sales = sales[sales.RegionName == 'Santa Clara'] #getting the data for the region Santa Clara
#dropping unwanted data
SCC_sales= SCC_sales[SCC_sales.columns.drop(list(SCC_sales.filter(regex='2008')))]
SCC_sales= SCC_sales[SCC_sales.columns.drop(list(SCC_sales.filter(regex='2009')))]
SCC_sales= SCC_sales[SCC_sales.columns.drop(list(SCC_sales.filter(regex='2010')))]
SCC_sales= SCC_sales[SCC_sales.columns.drop(list(SCC_sales.filter(regex='2011')))]
SCC_sales= SCC_sales[SCC_sales.columns.drop(list(SCC_sales.filter(regex='2012')))]

#transposing into columns
SCC_col = SCC_sales.transpose()
SCC_col.head()

#dropping unwanted columns
SCC_col = SCC_col.drop(['RegionID','RegionName','StateName','SizeRank'], axis=0)
SCC_col.head()

##Reset index
SCC_col.reset_index(level=0,inplace=True)

##Name columns
SCC_col.columns = ['YearMonth','Median_Sales_Price']

##Make a new column Year from YearMonth
SCC_col['Year']= (SCC_col['YearMonth'].str.split('-').str[0])

#Convert median sales price & year to numeric
SCC_col['Median_Sales_Price'] = SCC_col['Median_Sales_Price'].apply(pd.to_numeric)
SCC_col['Year'] = SCC_col['Year'].apply(pd.to_numeric)

##Make a new dataframe groupby year
SCC_MSP_year = SCC_col.groupby('Year', as_index=False).mean()
SCC_MSP_year

#merging the inventory for sales and the median sales price and then export CSV
mdf= SCC_MSP_year.merge(avg_inventory_santaclara, left_on = "Year", right_on = "Year")

#merge monthly level
monthly_mdf = SCC_col.merge(df_inventory_santaclara, left_on = "YearMonth", right_on = "YearMonth") # merged at monthly level for prediction graph
mdf.to_csv('Monthly_Sales_Inventory.csv')

from google.colab import files
mdf.to_csv('mdf.csv')
files.download('mdf.csv')
# Out:
#                      13
# RegionID           3136
# RegionName  Santa Clara
# StateName    California
# SizeRank             14
# 2013-01          632400
#              13
# 2013-01  632400
# 2013-02  634500
# 2013-03  635200
# 2013-04  633100
# 2013-05  646600
#    Year  Median_Sales_Price
# 0  2013        6.537417e+05
# 1  2014        7.162750e+05
# 2  2015        7.988833e+05
# 3  2016        8.583250e+05
# 4  2017        9.565500e+05
# 5  2018        1.161767e+06

# %% [markdown]
# #### Warrant:
#
# Using the merged Monthly_Sales_Inventory dataset:
#
# 1. We ran a regression in R between house price and inventory for sale from 2013 to 2017. The equation we got is **House Price = -81.43 \* Inventory for Sale + 9.686 \* Population Change + 1,114,000**. With this equation, we will predict how house prices vary with inventory and population change.
#
# 2. In Tableau, we created parameters for Inventory for Sale and Population Change in 2018, as well as a calculated field for 2018 House Price using our equation. We then made two graphs, one with the historical data where we set the x-axis to year and the y-axis to median sales price, and one where we instead set the y-axis to the calculated field. In the second graph, we showed only the 2018 prediction and hid the past data so we could align the calculated forecast with our original graph.
#
# 3. We decided to use a line graph since we wanted to see change over time, as well as it being easier for someone to compare the predicted line to the historical data.
#
# The chart is available in the following link and screenshot below.

# %%
from google.colab import files
uploaded = files.upload()

from pylab import imread,subplot,imshow,show

import matplotlib.pyplot as plt

image = imread('finding1.png')  # choose image location
plt.rcParams['figure.figsize'] = [20,20]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-f6428360-a2c9-4907-a24b-d41bf370754c" name="files[]" multiple disabled />
#      <output id="result-f6428360-a2c9-4907-a24b-d41bf370754c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving finding1.png to finding1 (2).png

# %% [markdown]
# [Tableau Link](https://public.tableau.com/profile/katharine.grant#!/vizhome/HousePriceandForecast/HousePriceandForecast)

# %% [markdown]
# **Interesting Aspect:**  We found that we can forecast the house prices by changing the inventory for sale and population change. House price is positively correlated to population change and negatively correlated with change in housing units. For every 1,000 people moving to the county, the house price rises by approximately 9,500 dollars. For every 100 new houses built, the house price lowers by approximately 8,000 dollars.
#
# **Limitation:** From the intercept, we can tell that if the population does not increase, the maximum of the median house price is only 1.1 million dollars, which while we know this is not realistic, the model creates a decent estimate for the purpose of our claim.
#
# **Backing:** With line graphs, it is easy for the audience to see the slope showing how quickly house prices have risen. Since the slope is positive, price is rising over time.
#
# **Qualifier:** The claim is true for only Santa Clara County in general, not for each city in the county and only for the time period from 2013 to 2017.
#
# **Rebuttal:** If we include more counties, then our findings may vary a bit but we have specifically mentioned our above qualifiers in the graph, so possible rebuttal is taken care of.

# %% [markdown]
# ### Finding 2: House Prices and Income

# %% [markdown]
# **Audience:** One of the main reasons high house prices are an important issue is because of affordability. The city council likely hears many complaints about how even for high-income workers, the house prices are still unaffordable. This graph will help the council see how house prices have become more unaffordable over time and how reducing the future increase in house price will benefit locals.
#
# **Claim:** House prices have been increasing faster than income, causing houses to become less affordable.

# %% [markdown]
# #### Data Collection & Wrangling
#
# To meet the need of the goal (as per GQM), we have used the following datasets:
#
# **Data Source:**
# We created the affordability dataset by combining two datasets from Zillow, [Zillow house prices](https://www.zillow.com/research/data/) and [Median Household Income](https://www.zillow.com/research/data/).
#
# The sales data includes monthly median sales prices by county. The income data includes the yearly median household income for Santa Clara County.
#
#
# **Data cleaning:** We needed to combine our house sales price data with our household median income data. Because the sales data was monthly while the income data was yearly, the first step (after cleaning up the columns and rows) was to aggregate the sales data by year. We were then able to merge the two datasets and compare the two trends.

# %% [markdown]
# **Dataset 1: House Prices**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ef1dd81b-388c-4860-b5bd-7a1c4c8f6352" name="files[]" multiple disabled />
#      <output id="result-ef1dd81b-388c-4860-b5bd-7a1c4c8f6352">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Sale_Prices_County_Aff.csv to Sale_Prices_County_Aff (1).csv

# %%
import pandas as pd
sales = pd.read_csv('Sale_Prices_County_Aff.csv')
SCC_sales = sales[sales.RegionName == 'Santa Clara']
SCC_col = SCC_sales.transpose()
SCC_col = SCC_col.drop(['RegionID','RegionName','StateName','SizeRank'], axis=0)
SCC_col.reset_index(level=0,inplace=True)
SCC_col.columns = ['YearMonth','Median_Sales_Price']
SCC_col['Year']= (SCC_col['YearMonth'].str.split('-').str[0])
SCC_col['Median_Sales_Price'] = SCC_col['Median_Sales_Price'].apply(pd.to_numeric)
SCC_col['Year'] = SCC_col['Year'].apply(pd.to_numeric)
SCC_MSP_year = SCC_col.groupby('Year').mean()
SCC_MSP_year.reset_index(level=0,inplace=True)
SCC_MSP_year.columns = ['Year','Median_Sales_Price']
#from google.colab import files
#SCC_MSP_year.to_csv('median_sale_price.csv')
#files.download('median_sale_price.csv')
df_merge_new = SCC_MSP_year.iloc[5:10,:]
df=df_merge_new.reset_index()
df_merge_update=df.iloc[:,2:3]
df_merge_update['Median_Sales_Price']
# Out:
# 0    653741.666667
# 1    716275.000000
# 2    798883.333333
# 3    858325.000000
# 4    956550.000000
# Name: Median_Sales_Price, dtype: float64

# %% [markdown]
# **Dataset 2: Household Median Income**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7363c044-dc93-4b7d-aa2a-228edbe02c88" name="files[]" multiple disabled />
#      <output id="result-7363c044-dc93-4b7d-aa2a-228edbe02c88">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Household Income Year 2013 to 2017.csv to Household Income Year 2013 to 2017.csv

# %%
import pandas as pd
income = pd.read_csv('Household Income Year 2013 to 2017.csv')
income_t = income.transpose().reset_index()
income_m = income_t.iloc[:,12:13]
income_m2= income_m.iloc[1:6,0:1]
income_m2.columns = ['Median household income']
income_year =income_t.iloc[:,0:0]
income_year2 = income_year.reset_index()
income_year3 =income_year2.iloc[1:6,0:1]
income_year3.columns = ['year']
income_data = pd.concat([income_year3,income_m2], axis=1)

# %%
income_data
# Out:
#    year Median household income
# 1     1                  91,702
# 2     2                  93,854
# 3     3                  96,310
# 4     4                 101,173
# 5     5                102,191

# %% [markdown]
# #### Warrant:
# We created the price to income ratio (median house price divided by median household income) which we have defined as our affordability index. The higher the ratio, the less affordable housing is for the general population.
#
# In Tableau, we set the year as the columns and the Price to Income Ratio as the rows. Since all of our other visualizations only include data since 2013, we then filtered the year to only 2013-2017 so that the previous decades would not distract from the current trend. We included a reference line for California's price to income ratio to highlight the fact that our affordability levels are not normal. We had considered including the ratio for the entire U.S. but it was so low (1.1 in 2017) that it would barely show on the graph and would be barely relevant to Santa Clara County.
#
# The chart is available in the following link and screenshot below.
#
# [Tableau Link](https://public.tableau.com/profile/katharine.grant#!/vizhome/Affordability_6/Affordability)

# %%
from google.colab import files
uploaded = files.upload()
from pylab import imread,subplot,imshow,show
import matplotlib.pyplot as plt
image = imread('Price_Income.jpeg')  # choose image location
plt.rcParams['figure.figsize'] = [22,30]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-6f6f2086-0047-4599-ae59-362249093f1e" name="files[]" multiple disabled />
#      <output id="result-6f6f2086-0047-4599-ae59-362249093f1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Price_Income.jpeg to Price_Income (4).jpeg

# %% [markdown]
# **Interesting Aspect:**
# For this visualization, we found that the house prices increase faster than median household income which suggests more and more people can't afford houses in Santa Clara County. This is important because the first step in convincing the council to increase housing is to show them that there is a problem with regards to house prices. As the audience increases the new housing variable, they can see that the price to income ratio reduces, meaning that the affordability improves.
#
# **Backing:** With line graphs, it is easy for the audience to see the slope showing how quickly house prices have become unaffordable. Since the slope is positive, the price to income ratio is rising over time.
#
# **Qualifier:** The claim is true for only Santa Clara County in general, not for each city in the county and only for the time period from 2013 to 2017.
#
# **Rebuttal:** If we include more counties, then our findings may vary a bit but we have specifically mentioned our above qualifiers in the graph, so possible rebuttal is taken care of.

# %% [markdown]
# ### Finding 3: Population and Housing Units

# %% [markdown]
# **Audience:** Two of the most important factors that we have considered with regards to house prices are the increase in population and the increase, or lack thereof, in housing. City council members are generally aware of the impact population and housing availability have on local house prices. However, their understanding of the connection is likely only conceptual and our visualizations will help them see the current trends and the variables' direct impact on house prices.
#
#
# **Claim:** Net migration to Santa Clara County has slowed while housing units have risen semi-consistently.

# %% [markdown]
# #### Data Collection & Wrangling
#
# To meet the need of the goal (as per GQM), we have used the following data sources:
#
# **Data Source:**
#
# Population dataset: https://fred.stlouisfed.org/series/CASANT5POP.
#
# Housing Units dataset: https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?src=CF
#
# For 2017, we found data at https://factfinder.census.gov/bkmk/table/1.0/en/PEP/2017/PEPANNHU/0500000US06085
#
# **Data cleaning:** To combine the house unit data with the population data, the first step (after cleaning up the columns and rows) was to convert the data to year. We were then able to merge the two datasets and compare the two trends. Detailed steps are shown below.

# %% [markdown]
# **Dataset 1: Population**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-978256b3-86a1-483b-9802-4972fb2d859e" name="files[]" multiple disabled />
#      <output id="result-978256b3-86a1-483b-9802-4972fb2d859e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Population_Santa Clara.csv to Population_Santa Clara.csv

# %%
Population= pd.read_csv('Population_Santa Clara.csv', skiprows=1)

##Make a new column Year from Date Column
Population['Year']=Population['Date'].str.split('/').str[2]

##Make a new dataframe with years from 2010 to 2018
Population_1 = Population.iloc[40:48, ]

## Drop Date column
Population_1 =Population_1.drop("Date", axis=1)

## Naming the  Columns
Population_1.columns=['Population_1','Year']

## Make a new column Population_2
Population_1['Population_2'] = Population_1['Population_1'].shift(1)

## Make a new column PopulationChange_in_Thousands
Population_1['PopulationChange_in_Thousands'] = pd.to_numeric(Population_1['Population_1']) - pd.to_numeric(Population_1['Population_2'])

##name the columns
Population_1=Population_1[['Year','Population_1','Population_2','PopulationChange_in_Thousands']]

##Drop unnecessary columns
Population_Final =Population_1.drop(['Population_1','Population_2'],axis=1)

##Convert year to numeric
Population_Final[['Year']] = Population_Final[['Year']].apply(pd.to_numeric)
Population_Final.head()
# Out:
#     Year  PopulationChange_in_Thousands
# 40  2010                            NaN
# 41  2011                         27.270
# 42  2012                         28.056
# 43  2013                         29.067
# 44  2014                         25.311

# %% [markdown]
# **Dataset 2: Housing Units**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a171fdb2-021c-4231-bdf5-2a6545986ec0" name="files[]" multiple disabled />
#      <output id="result-a171fdb2-021c-4231-bdf5-2a6545986ec0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Units1.csv to Units1.csv

# %%
#reading the csv
Units= pd.read_csv('Units1.csv', skiprows=1)
##Transpose
Units = Units.transpose() 

##Reset index
Units.reset_index(inplace=True)

##Name Columns
Units.columns=['index','Year','Units'] 

##Getting a new column from year column
Units['Year1']=Units['Year'].str.split('-').str[1]

##Make a new dataframe
Units_1=Units.iloc[6:14,2:]

## Make a new row with rows shifted
Units_1['Units2'] = Units_1['Units'].shift(1)

## Make a new column change and Convert to Numeric
Units_1['Change'] = pd.to_numeric(Units_1['Units'].str.replace(",","").str.strip()) - \
pd.to_numeric(Units_1['Units2'].str.replace(",","").str.strip())

##Make a new dataframe
Units_1 = Units_1.iloc[1:8, ]

##Reorder
Units_1=Units_1[['Year1','Units','Units2','Change']]

##Drop unncessary columns

Units_Final=Units_1.drop(['Units','Units2'],axis=1)

##Name the columns
Units_Final.columns=['Year','Units_Change']

##Convert Year to numeric
Units_Final[['Year']] = Units_Final[['Year']].apply(pd.to_numeric)
Units_Final.head(30)   

# Merge and exporting csv 
Population_Units= Population_Final.merge(Units_Final, left_on = "Year", right_on = "Year")
Population_Units

from google.colab import files
Population_Units.to_csv('Population_Units.csv')
files.download('Population_Units.csv')
# Out:
#     Year  Units_Change
# 7   2012        2759.0
# 8   2013        5124.0
# 9   2014        7218.0
# 10  2015        9517.0
# 11  2016        4490.0
# 12  2017        6064.0
#    Year  PopulationChange_in_Thousands  Units_Change
# 0  2012                         28.056        2759.0
# 1  2013                         29.067        5124.0
# 2  2014                         25.311        7218.0
# 3  2015                         22.974        9517.0
# 4  2016                         12.355        4490.0
# 5  2017                          6.578        6064.0

# %% [markdown]
# ####Warrant:
#
# To create this visualization, we used the Population_Units dataset created above. After creating a dual axis graph of both population and housing, we plotted two graphs:
#
# In the **housing graph**, we set Year as the X-axis and Units Change as the Y-axis. After experimenting with a bar graph, we chose to make it a line graph as we think it better shows how housing growth has risen semi-consistently over the years.
#
# In the** population graph**, we set Year as the X-axis and  Population Change as the Y-axis. After experimenting with a bar graph, we chose to make it a line graph as we think it better shows how population growth has slowed over the years.
#
# On each graph, we included the trend line so that the audience can see the change in the overall rate. On the housing graph, the trend line highlights the fact that while there has been yearly fluctuation in the number of houses built, the rate of new housing has not accelerated. On the population graph, the trend line reinforces the fact that migration has reduced over the last five years.
#
# The chart is available in the following link and screenshot below.
#
# [Tableau Link](https://public.tableau.com/profile/katharine.grant#!/vizhome/HousingandMigration/PopandUnits)

# %%
from google.colab import files
uploaded = files.upload()
from pylab import imread,subplot,imshow,show
import matplotlib.pyplot as plt
image = imread('Change_Population.jpeg')  # choose image location
plt.rcParams['figure.figsize'] = [22,22]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-41783078-f598-4f67-afac-4fe3f45c7d5b" name="files[]" multiple disabled />
#      <output id="result-41783078-f598-4f67-afac-4fe3f45c7d5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Change_Population.jpeg to Change_Population (2).jpeg

# %%
from google.colab import files
uploaded = files.upload()
from pylab import imread,subplot,imshow,show
import matplotlib.pyplot as plt
image = imread('Change_Housing.png')  # choose image location
plt.rcParams['figure.figsize'] = [22,22]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-a8b14c80-b23b-4ac2-b64c-a2d844d0ec10" name="files[]" multiple disabled />
#      <output id="result-a8b14c80-b23b-4ac2-b64c-a2d844d0ec10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Change_Housing.png to Change_Housing (1).png

# %% [markdown]
# **Interesting Aspect:**
# While housing units have increased every year, the rate of increased housing has not been consistent. Meanwhile, the net migration to Santa Clara County, while still positive, has reduced consistently over the last five years. While we do not want to make any conclusions with regards to causality, this may show how a lack of increased, and therefore affordable, housing has led to fewer people choosing to move to Santa Clara County.
#
# **Backing:** With line graphs, it is easy for the audience to see how much population and housing units have each increased. Since the slope of the trend line is slightly negative for housing and definitively negative for population, the audience can see that Santa Clara County is not booming as much as one may assume.
#
# **Qualifier:** The claim is true for only Santa Clara County in general, not for each city in the county and only for the time period from 2013 to 2017.
#
# **Rebuttal:** If we include more counties, then our findings may vary a bit but we have specifically mentioned our above qualifiers in the graph, so possible rebuttal is taken care of.

# %% [markdown]
# ### Dashboard Layout
#
# Our main goal was to show that housing can be increased without current homeowners losing value, so we put the Median Sales Price and Forecast and the adjustable inputs at the top where it will grab the most attention.
#
# The second graph then shows the increase in the Price to Income ratio. This highlights why the previously demonstrated higher house prices are a problem, as houses are becoming less and less affordable.
#
# The last two visualizations are details of how housing units and population have changed over the last five years. Though the gap between the increase in housing units and the increase in population were very large five years ago, the gap has narrowed, possibly due to fewer people choosing to move here. Seeing these trends in connection to the above prices and affordability will highlight our overall claim that changing the number of housing units can be used to moderate the median housing prices.
#
# The ranges set for the parameters are based on the minimums and maximums of the historical data with a few exeptions.
#
# [Tableau Link](https://public.tableau.com/profile/katharine.grant#!/vizhome/IncreasedHousingWillReduceOurHousingCrisis/FinalDashboard)

# %%
from google.colab import files
uploaded = files.upload()
from pylab import imread,subplot,imshow,show
import matplotlib.pyplot as plt
image = imread('Dashboard.png')  # choose image location
plt.rcParams['figure.figsize'] = [22,22]
plt.imshow(image)
plt.show()
# Out:
#      <input type="file" id="files-4cc3fb3a-7c90-47fd-963b-e6c045d98375" name="files[]" multiple disabled />
#      <output id="result-4cc3fb3a-7c90-47fd-963b-e6c045d98375">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Dashboard.png to Dashboard.png

# %% [markdown]
# ## 3. VIDEO
# ---
#
# The video for our project can be found here: https://www.youtube.com/watch?v=jh7kNE7xVwos

# %% [markdown]
# ## **4. ROADMAP**
#
# ---
#
#
#
# **Our roadmap is as follows:**
#
#
# 1. We would like to analyze how the median house prices change during recession, stagnation, and boom by including preset combinations of our parameters.
#
# 2. We would also like to expand the price to income ratio graph to include income brackets so that we can compare house prices against multiple income levels.
#
# 3. Santa Clara Downtown Study: A project called "Mission Town Center" to build 318 housing units at the corner of El Camino Real and Benton Street by Irvine Company is under progress. In the future, we would like to explore how this increase in housing units is going to affect the house prices in that area so that the city council has a concrete example of somewhere where they can take action.
#
# 4. While we have explored the effect of total inventory on house price, we would also like to explore the difference between increasing the number of single family houses and increasing the number of apartments or condos.
#
# 5. While the price to income ratio graph shows the disproportionate increase in house prices, a possible improvement would be to include data for nearby counties. If Santa Clara's ratio is either rising faster than or is higher than other Bay Area counties, then we will be able to emphasize the importance of more local housing.

# %% [markdown]
# ##5. REFERENCES
#
# ---
#
#
#
# 1. Data dig: Are foreign investors driving up real estate in your California neighborhood?
# https://calmatters.org/articles/data-dig-are-foreign-investors-driving-up-real-estate-in-your-california-neighborhood/
#
# 2. A Bay Area developer wants to build 4,400 sorely needed homes. Here's why it won't happen
# http://www.latimes.com/politics/la-pol-ca-small-city-controls-big-housing-project-20170728-story.html
#
# 3. Why did California’s major housing bill fail so quickly?
# https://www.mercurynews.com/2018/04/18/why-did-californias-major-housing-bill-fail-so-quickly/
#
# 4. The evolving urban form: The San Francisco Bay Area
# http://www.newgeography.com/content/004165-the-evolving-urban-form-the-san-francisco-bay-area
